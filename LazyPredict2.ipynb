# %% [markdown]
# <a href="https://colab.research.google.com/github/kirbytreat/lazypredict/blob/master/LazyPredict2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading https://files.pythonhosted.org/packages/5f/db/1566dca1050ea74e9474dca0f1e7bbffcb0c3e694cf92e7e6e7ef9fca3af/lazypredict-0.2.7-py2.py3-none-any.whl
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from lazypredict) (7.1.2)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.7

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data = load_breast_cancer()
X = data.data
y= data.target
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 30/30 [00:01<00:00, 25.34it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LinearSVC                          0.99  ...        0.03
# Perceptron                         0.99  ...        0.01
# LogisticRegression                 0.99  ...        0.04
# XGBClassifier                      0.98  ...        0.15
# SVC                                0.98  ...        0.02
# LabelPropagation                   0.98  ...        0.02
# LabelSpreading                     0.98  ...        0.03
# BaggingClassifier                  0.97  ...        0.05
# PassiveAggressiveClassifier        0.98  ...        0.01
# SGDClassifier                      0.98  ...        0.01
# RandomForestClassifier             0.97  ...        0.19
# CalibratedClassifierCV             0.98  ...        0.03
# QuadraticDiscriminantAnalysis      0.96  ...        0.01
# ExtraTreesClassifier               0.97  ...        0.12
# RidgeClassifierCV                  0.97  ...        0.01
# LGBMClassifier                     0.96  ...        0.10
# RidgeClassifier                    0.97  ...        0.02
# AdaBoostClassifier                 0.96  ...        0.14
# KNeighborsClassifier               0.96  ...        0.03
# BernoulliNB                        0.95  ...        0.01
# LinearDiscriminantAnalysis         0.96  ...        0.04
# GaussianNB                         0.95  ...        0.01
# NuSVC                              0.95  ...        0.02
# ExtraTreeClassifier                0.94  ...        0.01
# NearestCentroid                    0.95  ...        0.01
# DecisionTreeClassifier             0.93  ...        0.02
# CheckingClassifier                 0.36  ...        0.01
# DummyClassifier                    0.53  ...        0.01
#
# [28 rows x 5 columns]

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)
X = X.astype(np.float32)
offset = int(X.shape[0] * 0.9)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 39/39 [00:03<00:00, 11.68it/s]
# StackingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# [18:32:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
models
# Out:
#                                R-Squared  RMSE  Time Taken
# Model
# SVR                                 0.88  2.62        0.03
# XGBRegressor                        0.87  2.67        0.05
# NuSVR                               0.86  2.76        0.06
# RandomForestRegressor               0.86  2.78        0.38
# GradientBoostingRegressor           0.86  2.84        0.17
# BaggingRegressor                    0.85  2.93        0.05
# AdaBoostRegressor                   0.83  3.04        0.11
# HistGradientBoostingRegressor       0.83  3.06        0.28
# LGBMRegressor                       0.83  3.11        0.07
# KNeighborsRegressor                 0.83  3.12        0.01
# ExtraTreesRegressor                 0.82  3.14        0.21
# ExtraTreeRegressor                  0.76  3.66        0.01
# DecisionTreeRegressor               0.75  3.75        0.01
# MLPRegressor                        0.74  3.80        1.25
# HuberRegressor                      0.74  3.84        0.02
# LinearSVR                           0.72  3.95        0.01
# RidgeCV                             0.72  3.97        0.01
# BayesianRidge                       0.72  3.97        0.01
# Ridge                               0.72  3.97        0.01
# LinearRegression                    0.72  3.97        0.02
# TransformedTargetRegressor          0.72  3.97        0.01
# ElasticNetCV                        0.72  3.98        0.07
# LassoCV                             0.72  3.98        0.09
# LassoLarsIC                         0.72  3.98        0.01
# LassoLarsCV                         0.72  3.98        0.03
# Lars                                0.72  3.99        0.03
# LarsCV                              0.71  4.02        0.04
# SGDRegressor                        0.70  4.07        0.01
# ElasticNet                          0.69  4.16        0.01
# Lasso                               0.66  4.35        0.01
# RANSACRegressor                     0.65  4.41        0.08
# OrthogonalMatchingPursuitCV         0.59  4.78        0.03
# PassiveAggressiveRegressor          0.54  5.09        0.01
# GaussianProcessRegressor            0.43  5.65        0.05
# OrthogonalMatchingPursuit           0.38  5.89        0.02
# DummyRegressor                     -0.02  7.56        0.01
# LassoLars                          -0.02  7.56        0.01
# KernelRidge                        -8.25 22.74        0.04
